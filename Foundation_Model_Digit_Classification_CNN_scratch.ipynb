# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/khetansarvesh/CV/blob/main/Foundation_Model_Digit_Classification_CNN_scratch.ipynb)

# %%
import numpy as np
from scipy.signal import correlate2d
from scipy.signal import convolve2d

# %% [markdown]
# # Dataset

# %%
import tensorflow.keras as keras
import numpy as np
from keras.utils import to_categorical

# Load the Fashion MNIST dataset
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

X_train = train_images[:5000] / 255.0
y_train = train_labels[:5000]
y_train = to_categorical(y_train)

X_test = train_images[5000:10000] / 255.0
y_test = train_labels[5000:10000]
y_test = to_categorical(y_test)

# %% [markdown]
# # Training

# %%
class Convolution:

    def __init__(self, input_shape, filter_size, num_filters):
        input_height, input_width = input_shape
        self.num_filters = num_filters
        self.input_shape = input_shape

        # Size of outputs and filters
        self.filter_shape = (num_filters, filter_size, filter_size) # (3,3)
        self.output_shape = (num_filters, input_height - filter_size + 1, input_width - filter_size + 1)

        # initializing weights with random numbers
        self.filters = np.random.randn(*self.filter_shape)
        self.biases = np.random.randn(*self.output_shape)

    def forward(self, input_data):
        self.input_data = input_data

        # Initialized output
        output = np.zeros(self.output_shape)

        # Performing 2D Convolution (Cross-Correlation) without any padding
        for i in range(self.num_filters):
            output[i] = correlate2d(self.input_data, self.filters[i], mode="valid")

        # Applying Relu Activtion function on all the filters
        output = np.maximum(output, 0)

        return output

    def backward(self, inp_p_bp, lr):
        '''
        inp_p_bp : input received to this layer from the next layer during back propagation
        '''

        # initializing gradients
        opt_bp = np.zeros_like(self.input_data)
        dL_dfilters = np.zeros_like(self.filters)

        for i in range(self.num_filters):

                # Calculating the gradient of loss with respect to kernels/ weights
                dL_dfilters[i] = correlate2d(self.input_data, inp_p_bp[i],mode="valid")

                # Calculating the gradient of loss with respect to inputs
                opt_bp += convolve2d(inp_p_bp[i], self.filters[i], mode="full")

        # Updating the parameters with learning rate
        self.filters -= lr * dL_dfilters
        self.biases -= lr * inp_p_bp

        # returning the gradient for next layer back propagation
        return opt_bp

# %%
class MaxPool:

    def __init__(self, pool_size):
        self.pool_size = pool_size

    def forward(self, input_data):
        self.input_data = input_data
        self.num_filters, self.input_height, self.input_width = input_data.shape
        self.output_height = self.input_height // self.pool_size
        self.output_width = self.input_width // self.pool_size

        # Determining the output shape
        self.output = np.zeros((self.num_filters, self.output_height, self.output_width))

        # Iterating over different filters
        for f in range(self.num_filters):
            # Looping through the height
            for i in range(self.output_height):
                # looping through the width
                for j in range(self.output_width):

                    # Starting postition
                    start_i = i * self.pool_size
                    start_j = j * self.pool_size

                    # Ending Position
                    end_i = start_i + self.pool_size
                    end_j = start_j + self.pool_size

                    # Creating a patch from the input data
                    patch = input_data[f, start_i:end_i, start_j:end_j]

                    #Finding the maximum value from each patch/window
                    self.output[f, i, j] = np.max(patch)

        return self.output

    def backward(self, dL_dout, lr):

        # initializing output of backprop
        dL_dinput = np.zeros_like(self.input_data)

        for c in range(self.num_filters):
            for i in range(self.output_height):
                for j in range(self.output_width):
                    start_i = i * self.pool_size
                    start_j = j * self.pool_size

                    end_i = start_i + self.pool_size
                    end_j = start_j + self.pool_size
                    patch = self.input_data[c, start_i:end_i, start_j:end_j]

                    mask = patch == np.max(patch)

                    dL_dinput[c,start_i:end_i, start_j:end_j] = dL_dout[c, i, j] * mask

        return dL_dinput

# %%
class Fully_Connected:

    def __init__(self, input_size, output_size):
        self.input_size = input_size # Size of the inputs coming
        self.output_size = output_size # Size of the output producing
        self.weights = np.random.randn(output_size, self.input_size)
        self.biases = np.random.rand(output_size, 1)

    def softmax(self, z):
        # Shift the input values to avoid numerical instability
        shifted_z = z - np.max(z)
        exp_values = np.exp(shifted_z)
        sum_exp_values = np.sum(exp_values, axis=0)
        log_sum_exp = np.log(sum_exp_values)
        return exp_values / sum_exp_values

    def softmax_derivative(self, s):
        return np.diagflat(s) - np.dot(s, s.T)

    def forward(self, input_data):
        self.input_data = input_data

        # Flattening the inputs from the previous layer into a vector
        flattened_input = input_data.flatten().reshape(1, -1)
        self.z = np.dot(self.weights, flattened_input.T) + self.biases

        # Applying Softmax
        self.output = self.softmax(self.z)
        return self.output

    def backward(self, dL_dout, lr):
        # Calculate the gradient of the loss with respect to the pre-activation (z)
        dL_dy = np.dot(self.softmax_derivative(self.output), dL_dout)
        # Calculate the gradient of the loss with respect to the weights (dw)
        dL_dw = np.dot(dL_dy, self.input_data.flatten().reshape(1, -1))

        # Calculate the gradient of the loss with respect to the biases (db)
        dL_db = dL_dy

        # Calculate the gradient of the loss with respect to the input data (dL_dinput)
        dL_dinput = np.dot(self.weights.T, dL_dy)
        dL_dinput = dL_dinput.reshape(self.input_data.shape)

        # Update the weights and biases based on the learning rate and gradients
        self.weights -= lr * dL_dw
        self.biases -= lr * dL_db

        # Return the gradient of the loss with respect to the input data
        return dL_dinput

# %%
def cross_entropy_loss(predictions, targets):
    predictions = np.clip(predictions, 1e-7, 1 - 1e-7) # Avoid numerical instability by adding a small epsilon value
    return -np.sum(targets * np.log(predictions)) / 10

def cross_entropy_loss_gradient(actual_labels, predicted_probs):
    num_samples = actual_labels.shape[0]
    gradient = -actual_labels / (predicted_probs + 1e-7) / num_samples
    return gradient

# %%
conv = Convolution(X_train[0].shape, 6, 1)
pool = MaxPool(2)
full = Fully_Connected(121, 10)
lr = 0.01
epochs = 200

for epoch in range(epochs):
    total_loss = 0.0
    correct_predictions = 0

    for i in range(len(X_train)):

        # Forward pass
        conv_out = conv.forward(X_train[i])
        pool_out = pool.forward(conv_out)
        full_out = full.forward(pool_out)
        loss = cross_entropy_loss(full_out.flatten(), y_train[i])
        total_loss += loss

        # Converting to One-Hot encoding
        one_hot_pred = np.zeros_like(full_out)
        one_hot_pred[np.argmax(full_out)] = 1
        one_hot_pred = one_hot_pred.flatten()

        num_pred = np.argmax(one_hot_pred)
        num_y = np.argmax(y_train[i])

        if num_pred == num_y:
            correct_predictions += 1

        # Backward pass
        gradient = cross_entropy_loss_gradient(y_train[i], full_out.flatten()).reshape((-1, 1))
        full_back = full.backward(gradient, lr)
        pool_back = pool.backward(full_back, lr)
        conv_back = conv.backward(pool_back, lr)

    # Print epoch statistics
    average_loss = total_loss / len(X_train)
    accuracy = correct_predictions / len(X_train) * 100.0
    print(f"Epoch {epoch + 1}/{epochs} - Loss: {average_loss:.4f} - Accuracy: {accuracy:.2f}%")
# Out:
# Epoch 1/200 - Loss: 1.0685 - Accuracy: 22.94%
# Epoch 2/200 - Loss: 1.0122 - Accuracy: 35.06%
# Epoch 3/200 - Loss: 0.9646 - Accuracy: 38.00%
# Epoch 4/200 - Loss: 0.9350 - Accuracy: 40.18%
# Epoch 5/200 - Loss: 0.9171 - Accuracy: 41.16%
# Epoch 6/200 - Loss: 0.9076 - Accuracy: 42.04%
# Epoch 7/200 - Loss: 0.9007 - Accuracy: 42.70%
# Epoch 8/200 - Loss: 0.8980 - Accuracy: 42.74%
# Epoch 9/200 - Loss: 0.8914 - Accuracy: 43.08%
# Epoch 10/200 - Loss: 0.8850 - Accuracy: 43.66%
# Epoch 11/200 - Loss: 0.8846 - Accuracy: 43.80%
# Epoch 12/200 - Loss: 0.8825 - Accuracy: 44.00%
# Epoch 13/200 - Loss: 0.8795 - Accuracy: 44.18%
# Epoch 14/200 - Loss: 0.8796 - Accuracy: 44.30%
# Epoch 15/200 - Loss: 0.8780 - Accuracy: 44.18%
# Epoch 16/200 - Loss: 0.8749 - Accuracy: 44.70%
# Epoch 17/200 - Loss: 0.8731 - Accuracy: 44.66%
# Epoch 18/200 - Loss: 0.8729 - Accuracy: 44.74%
# Epoch 19/200 - Loss: 0.8720 - Accuracy: 44.92%
# Epoch 20/200 - Loss: 0.8715 - Accuracy: 44.86%
# Epoch 21/200 - Loss: 0.8698 - Accuracy: 44.88%
# Epoch 22/200 - Loss: 0.8669 - Accuracy: 45.20%
# Epoch 23/200 - Loss: 0.8679 - Accuracy: 45.04%
# Epoch 24/200 - Loss: 0.8650 - Accuracy: 45.30%
# Epoch 25/200 - Loss: 0.8643 - Accuracy: 45.38%
# Epoch 26/200 - Loss: 0.8616 - Accuracy: 45.66%
# Epoch 27/200 - Loss: 0.8624 - Accuracy: 45.58%
# Epoch 28/200 - Loss: 0.8598 - Accuracy: 45.62%
# Epoch 29/200 - Loss: 0.8563 - Accuracy: 45.92%
# Epoch 30/200 - Loss: 0.8555 - Accuracy: 46.02%
# Epoch 31/200 - Loss: 0.8567 - Accuracy: 45.86%
# Epoch 32/200 - Loss: 0.8547 - Accuracy: 45.82%
# Epoch 33/200 - Loss: 0.8539 - Accuracy: 45.82%
# Epoch 34/200 - Loss: 0.8526 - Accuracy: 46.04%
# Epoch 35/200 - Loss: 0.8523 - Accuracy: 46.10%
# Epoch 36/200 - Loss: 0.8502 - Accuracy: 46.10%
# Epoch 37/200 - Loss: 0.8507 - Accuracy: 46.20%
# Epoch 38/200 - Loss: 0.8498 - Accuracy: 46.26%
# Epoch 39/200 - Loss: 0.8511 - Accuracy: 46.14%
# Epoch 40/200 - Loss: 0.8495 - Accuracy: 46.40%
# Epoch 41/200 - Loss: 0.8493 - Accuracy: 46.36%
# Epoch 42/200 - Loss: 0.8465 - Accuracy: 46.70%
# Epoch 43/200 - Loss: 0.8450 - Accuracy: 46.78%
# Epoch 44/200 - Loss: 0.8460 - Accuracy: 46.58%
# Epoch 45/200 - Loss: 0.8441 - Accuracy: 46.76%
# Epoch 46/200 - Loss: 0.8456 - Accuracy: 46.60%
# Epoch 47/200 - Loss: 0.8446 - Accuracy: 46.70%
# Epoch 48/200 - Loss: 0.8443 - Accuracy: 46.64%
# Epoch 49/200 - Loss: 0.8432 - Accuracy: 46.82%
# Epoch 50/200 - Loss: 0.8454 - Accuracy: 46.52%
# Epoch 51/200 - Loss: 0.8442 - Accuracy: 46.72%
# Epoch 52/200 - Loss: 0.8441 - Accuracy: 46.88%
# Epoch 53/200 - Loss: 0.8429 - Accuracy: 46.86%
# Epoch 54/200 - Loss: 0.8421 - Accuracy: 46.72%
# Epoch 55/200 - Loss: 0.8420 - Accuracy: 46.92%
# Epoch 56/200 - Loss: 0.8415 - Accuracy: 46.96%
# Epoch 57/200 - Loss: 0.8419 - Accuracy: 46.86%
# Epoch 58/200 - Loss: 0.8412 - Accuracy: 47.06%
# Epoch 59/200 - Loss: 0.8399 - Accuracy: 47.16%
# Epoch 60/200 - Loss: 0.8408 - Accuracy: 47.08%
# Epoch 61/200 - Loss: 0.8396 - Accuracy: 47.24%
# Epoch 62/200 - Loss: 0.8396 - Accuracy: 47.16%
# Epoch 63/200 - Loss: 0.8397 - Accuracy: 47.08%
# Epoch 64/200 - Loss: 0.8390 - Accuracy: 47.20%
# Epoch 65/200 - Loss: 0.8380 - Accuracy: 47.22%
# Epoch 66/200 - Loss: 0.8406 - Accuracy: 47.00%
# Epoch 67/200 - Loss: 0.8392 - Accuracy: 47.26%
# Epoch 68/200 - Loss: 0.8388 - Accuracy: 47.18%
# Epoch 69/200 - Loss: 0.8385 - Accuracy: 47.38%
# Epoch 70/200 - Loss: 0.8377 - Accuracy: 47.42%
# Epoch 71/200 - Loss: 0.8379 - Accuracy: 47.32%
# Epoch 72/200 - Loss: 0.8378 - Accuracy: 47.34%
# Epoch 73/200 - Loss: 0.8376 - Accuracy: 47.50%
# Epoch 74/200 - Loss: 0.8371 - Accuracy: 47.36%
# Epoch 75/200 - Loss: 0.8371 - Accuracy: 47.36%
# Epoch 76/200 - Loss: 0.8371 - Accuracy: 47.44%
# Epoch 77/200 - Loss: 0.8362 - Accuracy: 47.60%
# Epoch 78/200 - Loss: 0.8363 - Accuracy: 47.56%
# Epoch 79/200 - Loss: 0.8360 - Accuracy: 47.50%
# Epoch 80/200 - Loss: 0.8363 - Accuracy: 47.38%
# Epoch 81/200 - Loss: 0.8368 - Accuracy: 47.50%
# Epoch 82/200 - Loss: 0.8370 - Accuracy: 47.52%
# Epoch 83/200 - Loss: 0.8361 - Accuracy: 47.64%
# Epoch 84/200 - Loss: 0.8367 - Accuracy: 47.52%
# Epoch 85/200 - Loss: 0.8363 - Accuracy: 47.52%
# Epoch 86/200 - Loss: 0.8366 - Accuracy: 47.58%
# Epoch 87/200 - Loss: 0.8356 - Accuracy: 47.64%
# Epoch 88/200 - Loss: 0.8350 - Accuracy: 47.64%
# Epoch 89/200 - Loss: 0.8362 - Accuracy: 47.64%
# Epoch 90/200 - Loss: 0.8381 - Accuracy: 47.46%
# Epoch 91/200 - Loss: 0.8363 - Accuracy: 47.46%
# Epoch 92/200 - Loss: 0.8360 - Accuracy: 47.62%
# Epoch 93/200 - Loss: 0.8354 - Accuracy: 47.68%
# Epoch 94/200 - Loss: 0.8361 - Accuracy: 47.54%
# Epoch 95/200 - Loss: 0.8354 - Accuracy: 47.62%
# Epoch 96/200 - Loss: 0.8358 - Accuracy: 47.48%
# Epoch 97/200 - Loss: 0.8355 - Accuracy: 47.56%
# Epoch 98/200 - Loss: 0.8356 - Accuracy: 47.66%
# Epoch 99/200 - Loss: 0.8348 - Accuracy: 47.76%
# Epoch 100/200 - Loss: 0.8342 - Accuracy: 47.76%
# Epoch 101/200 - Loss: 0.8354 - Accuracy: 47.62%
# Epoch 102/200 - Loss: 0.8350 - Accuracy: 47.70%
# Epoch 103/200 - Loss: 0.8345 - Accuracy: 47.74%
# Epoch 104/200 - Loss: 0.8344 - Accuracy: 47.72%
# Epoch 105/200 - Loss: 0.8341 - Accuracy: 47.64%
# Epoch 106/200 - Loss: 0.8368 - Accuracy: 47.44%
# Epoch 107/200 - Loss: 0.8338 - Accuracy: 47.74%
# Epoch 108/200 - Loss: 0.8350 - Accuracy: 47.52%
# Epoch 109/200 - Loss: 0.8346 - Accuracy: 47.68%
# Epoch 110/200 - Loss: 0.8341 - Accuracy: 47.88%
# Epoch 111/200 - Loss: 0.8335 - Accuracy: 47.84%
# Epoch 112/200 - Loss: 0.8341 - Accuracy: 47.74%
# Epoch 113/200 - Loss: 0.8342 - Accuracy: 47.76%
# Epoch 114/200 - Loss: 0.8330 - Accuracy: 47.98%
# Epoch 115/200 - Loss: 0.8338 - Accuracy: 47.72%
# Epoch 116/200 - Loss: 0.8340 - Accuracy: 47.76%
# Epoch 117/200 - Loss: 0.8330 - Accuracy: 47.88%
# Epoch 118/200 - Loss: 0.8337 - Accuracy: 47.92%
# Epoch 119/200 - Loss: 0.8328 - Accuracy: 47.96%
# Epoch 120/200 - Loss: 0.8332 - Accuracy: 47.94%
# Epoch 121/200 - Loss: 0.8343 - Accuracy: 47.78%
# Epoch 122/200 - Loss: 0.8333 - Accuracy: 47.96%
# Epoch 123/200 - Loss: 0.8340 - Accuracy: 47.78%
# Epoch 124/200 - Loss: 0.8326 - Accuracy: 47.94%
# Epoch 125/200 - Loss: 0.8335 - Accuracy: 47.90%
# Epoch 126/200 - Loss: 0.8329 - Accuracy: 47.92%
# Epoch 127/200 - Loss: 0.8331 - Accuracy: 47.96%
# Epoch 128/200 - Loss: 0.8324 - Accuracy: 47.80%
# Epoch 129/200 - Loss: 0.8277 - Accuracy: 47.76%
# Epoch 130/200 - Loss: 0.7621 - Accuracy: 50.80%
# Epoch 131/200 - Loss: 0.7220 - Accuracy: 53.30%
# Epoch 132/200 - Loss: 0.7126 - Accuracy: 54.16%
# Epoch 133/200 - Loss: 0.7117 - Accuracy: 54.40%
# Epoch 134/200 - Loss: 0.7081 - Accuracy: 54.58%
# Epoch 135/200 - Loss: 0.7064 - Accuracy: 54.74%
# Epoch 136/200 - Loss: 0.7037 - Accuracy: 54.86%
# Epoch 137/200 - Loss: 0.7001 - Accuracy: 55.28%
# Epoch 138/200 - Loss: 0.6984 - Accuracy: 55.42%
# Epoch 139/200 - Loss: 0.6992 - Accuracy: 55.12%
# Epoch 140/200 - Loss: 0.6979 - Accuracy: 55.28%
# Epoch 141/200 - Loss: 0.6982 - Accuracy: 55.18%
# Epoch 142/200 - Loss: 0.6996 - Accuracy: 55.10%
# Epoch 143/200 - Loss: 0.7004 - Accuracy: 55.24%
# Epoch 144/200 - Loss: 0.7030 - Accuracy: 54.72%
# Epoch 145/200 - Loss: 0.7047 - Accuracy: 54.80%
# Epoch 146/200 - Loss: 0.7017 - Accuracy: 55.08%
# Epoch 147/200 - Loss: 0.7014 - Accuracy: 55.12%
# Epoch 148/200 - Loss: 0.7030 - Accuracy: 55.04%
# Epoch 149/200 - Loss: 0.7035 - Accuracy: 54.98%
# Epoch 150/200 - Loss: 0.7016 - Accuracy: 54.98%
# Epoch 151/200 - Loss: 0.7042 - Accuracy: 54.82%
# Epoch 152/200 - Loss: 0.6888 - Accuracy: 55.88%
# Epoch 153/200 - Loss: 0.6849 - Accuracy: 55.80%
# Epoch 154/200 - Loss: 0.6734 - Accuracy: 56.82%
# Epoch 155/200 - Loss: 0.6778 - Accuracy: 56.34%
# Epoch 156/200 - Loss: 0.6603 - Accuracy: 57.62%
# Epoch 157/200 - Loss: 0.6494 - Accuracy: 58.50%
# Epoch 158/200 - Loss: 0.6451 - Accuracy: 58.38%
# Epoch 159/200 - Loss: 0.6419 - Accuracy: 58.90%
# Epoch 160/200 - Loss: 0.6412 - Accuracy: 58.74%
# Epoch 161/200 - Loss: 0.6420 - Accuracy: 58.74%
# Epoch 162/200 - Loss: 0.6301 - Accuracy: 59.50%
# Epoch 163/200 - Loss: 0.6303 - Accuracy: 59.68%
# Epoch 164/200 - Loss: 0.6227 - Accuracy: 60.18%
# Epoch 165/200 - Loss: 0.6220 - Accuracy: 60.10%
# Epoch 166/200 - Loss: 0.6210 - Accuracy: 60.26%
# Epoch 167/200 - Loss: 0.6187 - Accuracy: 60.28%
# Epoch 168/200 - Loss: 0.6181 - Accuracy: 60.42%
# Epoch 169/200 - Loss: 0.6187 - Accuracy: 60.26%
# Epoch 170/200 - Loss: 0.6075 - Accuracy: 61.30%
# Epoch 171/200 - Loss: 0.6131 - Accuracy: 60.90%
# Epoch 172/200 - Loss: 0.6099 - Accuracy: 60.94%
# Epoch 173/200 - Loss: 0.6171 - Accuracy: 60.62%
# Epoch 174/200 - Loss: 0.6107 - Accuracy: 61.06%
# Epoch 175/200 - Loss: 0.6179 - Accuracy: 60.66%
# Epoch 176/200 - Loss: 0.6126 - Accuracy: 60.90%
# Epoch 177/200 - Loss: 0.6290 - Accuracy: 59.80%
# Epoch 178/200 - Loss: 0.6085 - Accuracy: 61.20%
# Epoch 179/200 - Loss: 0.6084 - Accuracy: 61.36%
# Epoch 180/200 - Loss: 0.6082 - Accuracy: 61.00%
# Epoch 181/200 - Loss: 0.6062 - Accuracy: 61.34%
# Epoch 182/200 - Loss: 0.6132 - Accuracy: 61.18%
# Epoch 183/200 - Loss: 0.6028 - Accuracy: 61.72%
# Epoch 184/200 - Loss: 0.6103 - Accuracy: 61.08%
# Epoch 185/200 - Loss: 0.6129 - Accuracy: 60.98%
# Epoch 186/200 - Loss: 0.6023 - Accuracy: 61.60%
# Epoch 187/200 - Loss: 0.6048 - Accuracy: 61.44%
# Epoch 188/200 - Loss: 0.6042 - Accuracy: 61.78%
# Epoch 189/200 - Loss: 0.6024 - Accuracy: 61.68%
# Epoch 190/200 - Loss: 0.6108 - Accuracy: 61.22%
# Epoch 191/200 - Loss: 0.5990 - Accuracy: 61.90%
# Epoch 192/200 - Loss: 0.6083 - Accuracy: 61.32%
# Epoch 193/200 - Loss: 0.6143 - Accuracy: 60.84%
# Epoch 194/200 - Loss: 0.6106 - Accuracy: 60.98%
# Epoch 195/200 - Loss: 0.6097 - Accuracy: 61.44%
# Epoch 196/200 - Loss: 0.6041 - Accuracy: 61.70%
# Epoch 197/200 - Loss: 0.6210 - Accuracy: 60.56%
# Epoch 198/200 - Loss: 0.6085 - Accuracy: 61.24%
# Epoch 199/200 - Loss: 0.6099 - Accuracy: 61.24%
# Epoch 200/200 - Loss: 0.6048 - Accuracy: 61.58%

# %% [markdown]
# # Inference

# %%
predictions = []
for data in X_test:
    conv_out = conv.forward(data)
    pool_out = pool.forward(conv_out)
    flattened_output = pool_out.flatten()
    pred = full.forward(flattened_output)
    one_hot_pred = np.zeros_like(pred)
    one_hot_pred[np.argmax(pred)] = 1
    predictions.append(one_hot_pred.flatten())
predictions = np.array(predictions)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(predictions, y_test)
# Out:
# 0.5766
