# %%
#!pip install "gym[accept-rom-license, atari]"
import pickle

import numpy as np
import torch
import gym

import torch
import torch.nn as nn
import torch.nn.functional as F

import torch.optim as optim

# %%
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()

        self.fc1 = nn.Linear(80 * 80 * 1, 200)
        self.fc2 = nn.Linear(200, 1)

    def forward(self, x):
        # Ensure the input is in float format
        x = x.float()
        # mlp layers
        x = F.relu(self.fc1(x))  # Hidden layer (200)
        x = torch.sigmoid(self.fc2(x))  # Single output with sigmoid
        return x

class SmallCNN(nn.Module):
    def __init__(self):
        super(SmallCNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=1, out_channels=1, kernel_size=3, stride=2, padding=1)  # Downsampling
        self.conv2 = nn.Conv2d(in_channels=1, out_channels=1, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(80 * 80 * 1, 200)
        self.fc2 = nn.Linear(200, 1)

    def forward(self, x):
        # Ensure the input is in float format
        x = x.float()
        x = F.relu(self.conv1(x))  # Downsampling (160 -> 80)
        x = F.relu(self.conv2(x))  # Same size (80 -> 80)
        x = x.view(x.size(0), -1)  # Flatten to (batch_size, 80*80*1)
        # mlp layers
        x = F.relu(self.fc1(x))  # Hidden layer (200)
        x = torch.sigmoid(self.fc2(x))  # Single output with sigmoid

        return x

# %%
def prepro_mlp(I):
  """ prepro 210x160x3 uint8 frame into 6400 (80x80) 1D float vector """
  I = I[35:195] # crop
  I = I[::2,::2,0] # downsample by factor of 2 --- (80, 80)
  I[I == 144] = 0 # erase background (background type 1)
  I[I == 109] = 0 # erase background (background type 2)
  I[I != 0] = 1 # everything else (paddles, ball) just set to 1 -- still of shape (80, 80)
  return torch.tensor(I.astype(float).ravel()).unsqueeze(0)

def preprocess_v1(I):
  """ prepro 210x160x3 uint8 frame into torch (80x80) vector """
  I = I[35:195] # crop
  I = I[:,:,0] # Only take first channel
  I[I == 144] = 0 # erase background (background type 1)
  I[I == 109] = 0 # erase background (background type 2)
  I[I != 0] = 1 # everything else (paddles, ball) just set to 1
  I = torch.tensor(I.astype(float)).unsqueeze(0).unsqueeze(0) # (1, 1, 160, 160) shape
  return I

def discount_rewards_v1(r):
    """ take torch tensor of shape (batch, reward) and compute discounted reward """
    discounted_r = torch.zeros_like(r).to(device)
    running_add = 0.0
    for t in reversed(range(0, r.size(0))):
        if r[t] != 0.0: running_add = 0.0 # reset the sum, since this was a game boundary (pong specific!)
        running_add = running_add * 0.99 + r[t]
        discounted_r[t] = running_add
    return discounted_r

# %%
env = gym.make("ALE/Pong-v5")
observation = env.reset()
prev_x = None # used in computing the difference frame
reward_sum = 0
episode_number = 0

device = "cuda" if torch.cuda.is_available() else "cpu"
model = SmallCNN().to(device)
bce_loss = nn.BCELoss(reduction='none')
optimizer = optim.Adam(model.parameters(), lr=1e-2)

# %%
cnt_matches = 0
while True:

    x = preprocess_v1(observation)
    aprob = model(x.to(device))
    action = 2 if np.random.uniform() < aprob.item() else 3 # flipping a random coin

    # y is "fake label" -- considering this as a label for this observation --- to move "UP" y = 1
    y = 1 if action == 2 else 0
    y = torch.tensor([y], dtype=torch.float).unsqueeze(0).to(device) # (batch, target)

    # step the environment and get new measurements
    observation, reward, done, info = env.step(action) # done=True when episode will end, an episode equals to one full game played until one wins 21 matches.
    reward_sum += reward

    # storing reward of each match
    if reward != 0: #i.e. match ended
      cnt_matches += 1
      print(f'ep {episode_number}: (match {cnt_matches}) game finished, reward: {reward}')

    reward = torch.tensor([reward], dtype=torch.float).unsqueeze(0).to(device) # (batch, reward)


    if cnt_matches == 1:
      rs = reward
    else:
      rs = torch.cat((rs, reward), dim=0).to(device) # creating batch of rewards of a each match -- (batch, target)

    if done: # one episode i.e. one game is finished
        episode_number += 1

        discounted_rs = discount_rewards_v1(rs) # rs -- torch.size((batch, rewards))
        discounted_rs = (discounted_rs - torch.mean(discounted_rs)) / torch.std(discounted_rs) # discounted_rs like weights for loss of each batch

        # Compute the loss for each element
        loss_per_element = bce_loss(aprob, y) # e.g. batch_probs - shape: (30, 1), ys - shape: (30, 1), loss_per_element - (30, 1)
        weighted_loss = loss_per_element * discounted_rs.to(device) # e.g. discounted_rs - shape: (30, 1), weighted_loss - (30, 1)
        loss = weighted_loss.mean()

        # Backward pass
        loss.backward() # store the calculated gradient of each parameter

        if episode_number % 2 == 0: # update parameters of model when episode is multiple of batch_size
            # update weights of the model
            optimizer.step()  # Update weights
            optimizer.zero_grad()  # Reset gradients, as for batch_size (e.g. 10), gradient of each episode was accumulating.
            print("loss :", loss.item())

        # boring book-keeping
        print(f'resetting env. episode reward total was {reward_sum}')
        print(f'total matches played in this episode: {cnt_matches}, Note: To change episode, one player should win 21 matches.')

        if episode_number  == 30:
            break

        reward_sum = 0
        cnt_matches = 0
        observation = env.reset() # reset env
# Out:
# ep 0: (match 1) game finished, reward: -1.0
# ep 0: (match 2) game finished, reward: -1.0
# ep 0: (match 3) game finished, reward: -1.0
# ep 0: (match 4) game finished, reward: -1.0
# ep 0: (match 5) game finished, reward: -1.0
# ep 0: (match 6) game finished, reward: -1.0
# ep 0: (match 7) game finished, reward: -1.0
# ep 0: (match 8) game finished, reward: -1.0
# ep 0: (match 9) game finished, reward: -1.0
# ep 0: (match 10) game finished, reward: -1.0
# ep 0: (match 11) game finished, reward: -1.0
# ep 0: (match 12) game finished, reward: -1.0
# ep 0: (match 13) game finished, reward: -1.0
# ep 0: (match 14) game finished, reward: -1.0
# ep 0: (match 15) game finished, reward: -1.0
# ep 0: (match 16) game finished, reward: -1.0
# ep 0: (match 17) game finished, reward: -1.0
# ep 0: (match 18) game finished, reward: -1.0
# ep 0: (match 19) game finished, reward: -1.0
# ep 0: (match 20) game finished, reward: -1.0
# ep 0: (match 21) game finished, reward: -1.0
# resetting env. episode reward total was -21.0
# total matches played in this episode: 21, Note: To change episode, one player should win 21 matches.
# ep 1: (match 1) game finished, reward: -1.0
# ep 1: (match 2) game finished, reward: -1.0
# ep 1: (match 3) game finished, reward: -1.0
# ep 1: (match 4) game finished, reward: -1.0
# ep 1: (match 5) game finished, reward: -1.0
# ep 1: (match 6) game finished, reward: -1.0
# ep 1: (match 7) game finished, reward: -1.0
# ep 1: (match 8) game finished, reward: -1.0
# ep 1: (match 9) game finished, reward: -1.0
# ep 1: (match 10) game finished, reward: -1.0
# ep 1: (match 11) game finished, reward: -1.0
# ep 1: (match 12) game finished, reward: -1.0
# ep 1: (match 13) game finished, reward: -1.0
# ep 1: (match 14) game finished, reward: -1.0
# ep 1: (match 15) game finished, reward: -1.0
# ep 1: (match 16) game finished, reward: -1.0
# ep 1: (match 17) game finished, reward: -1.0
# ep 1: (match 18) game finished, reward: -1.0
# ep 1: (match 19) game finished, reward: -1.0
# ep 1: (match 20) game finished, reward: -1.0
# ep 1: (match 21) game finished, reward: -1.0
# loss : -9.172102721777264e-08
# resetting env. episode reward total was -21.0
# total matches played in this episode: 21, Note: To change episode, one player should win 21 matches.
# ep 2: (match 1) game finished, reward: -1.0
# ep 2: (match 2) game finished, reward: -1.0
# ep 2: (match 3) game finished, reward: -1.0
# ep 2: (match 4) game finished, reward: -1.0
# ep 2: (match 5) game finished, reward: -1.0
# ep 2: (match 6) game finished, reward: -1.0
# ep 2: (match 7) game finished, reward: -1.0
# ep 2: (match 8) game finished, reward: -1.0
# ep 2: (match 9) game finished, reward: -1.0
# ep 2: (match 10) game finished, reward: -1.0
# ep 2: (match 11) game finished, reward: -1.0
# ep 2: (match 12) game finished, reward: -1.0
# ep 2: (match 13) game finished, reward: -1.0
# ep 2: (match 14) game finished, reward: -1.0
# ep 2: (match 15) game finished, reward: -1.0
# ep 2: (match 16) game finished, reward: -1.0
# ep 2: (match 17) game finished, reward: -1.0
# ep 2: (match 18) game finished, reward: -1.0
# ep 2: (match 19) game finished, reward: -1.0
# ep 2: (match 20) game finished, reward: -1.0
# ep 2: (match 21) game finished, reward: -1.0
# resetting env. episode reward total was -21.0
# total matches played in this episode: 21, Note: To change episode, one player should win 21 matches.
# ep 3: (match 1) game finished, reward: -1.0
# ep 3: (match 2) game finished, reward: -1.0
# ep 3: (match 3) game finished, reward: -1.0
# ep 3: (match 4) game finished, reward: -1.0
# ep 3: (match 5) game finished, reward: -1.0
# ep 3: (match 6) game finished, reward: -1.0
# ep 3: (match 7) game finished, reward: -1.0
# ep 3: (match 8) game finished, reward: -1.0
# ep 3: (match 9) game finished, reward: -1.0
# ep 3: (match 10) game finished, reward: -1.0
# ep 3: (match 11) game finished, reward: -1.0
# ep 3: (match 12) game finished, reward: -1.0
# ep 3: (match 13) game finished, reward: -1.0
# ep 3: (match 14) game finished, reward: -1.0
# ep 3: (match 15) game finished, reward: -1.0
# ep 3: (match 16) game finished, reward: 1.0
# ep 3: (match 17) game finished, reward: -1.0
# ep 3: (match 18) game finished, reward: -1.0
# ep 3: (match 19) game finished, reward: -1.0
# ep 3: (match 20) game finished, reward: -1.0
# ep 3: (match 21) game finished, reward: -1.0
# ep 3: (match 22) game finished, reward: -1.0
# loss : 5.5764900253052474e-08
# resetting env. episode reward total was -20.0
# total matches played in this episode: 22, Note: To change episode, one player should win 21 matches.
# ep 4: (match 1) game finished, reward: -1.0
# ep 4: (match 2) game finished, reward: -1.0
# ep 4: (match 3) game finished, reward: -1.0
# ep 4: (match 4) game finished, reward: -1.0
# ep 4: (match 5) game finished, reward: -1.0
# ep 4: (match 6) game finished, reward: -1.0
# ep 4: (match 7) game finished, reward: -1.0
# ep 4: (match 8) game finished, reward: -1.0
# ep 4: (match 9) game finished, reward: -1.0
# ep 4: (match 10) game finished, reward: -1.0
# ep 4: (match 11) game finished, reward: -1.0
# ep 4: (match 12) game finished, reward: -1.0
# ep 4: (match 13) game finished, reward: -1.0
# ep 4: (match 14) game finished, reward: -1.0
# ep 4: (match 15) game finished, reward: -1.0
# ep 4: (match 16) game finished, reward: -1.0
# ep 4: (match 17) game finished, reward: -1.0
# ep 4: (match 18) game finished, reward: -1.0
# ep 4: (match 19) game finished, reward: -1.0
# ep 4: (match 20) game finished, reward: -1.0
# ep 4: (match 21) game finished, reward: -1.0
# resetting env. episode reward total was -21.0
# total matches played in this episode: 21, Note: To change episode, one player should win 21 matches.
# ep 5: (match 1) game finished, reward: -1.0
# ep 5: (match 2) game finished, reward: -1.0
# ep 5: (match 3) game finished, reward: -1.0
# ep 5: (match 4) game finished, reward: -1.0
# ep 5: (match 5) game finished, reward: -1.0
# ep 5: (match 6) game finished, reward: -1.0
# ep 5: (match 7) game finished, reward: -1.0
# ep 5: (match 8) game finished, reward: -1.0
# ep 5: (match 9) game finished, reward: -1.0
# ep 5: (match 10) game finished, reward: -1.0
# ep 5: (match 11) game finished, reward: -1.0
# ep 5: (match 12) game finished, reward: -1.0
# ep 5: (match 13) game finished, reward: -1.0
# ep 5: (match 14) game finished, reward: -1.0
# ep 5: (match 15) game finished, reward: -1.0
# ep 5: (match 16) game finished, reward: -1.0
# ep 5: (match 17) game finished, reward: -1.0
# ep 5: (match 18) game finished, reward: 1.0
# ep 5: (match 19) game finished, reward: -1.0
# ep 5: (match 20) game finished, reward: -1.0
# ep 5: (match 21) game finished, reward: -1.0
# ep 5: (match 22) game finished, reward: -1.0
# loss : 6.105533856270995e-08
# resetting env. episode reward total was -20.0
# total matches played in this episode: 22, Note: To change episode, one player should win 21 matches.
# ep 6: (match 1) game finished, reward: -1.0
# ep 6: (match 2) game finished, reward: -1.0
# ep 6: (match 3) game finished, reward: -1.0
# ep 6: (match 4) game finished, reward: -1.0
# ep 6: (match 5) game finished, reward: -1.0
# ep 6: (match 6) game finished, reward: -1.0
# ep 6: (match 7) game finished, reward: -1.0
# ep 6: (match 8) game finished, reward: 1.0
# ep 6: (match 9) game finished, reward: -1.0
# ep 6: (match 10) game finished, reward: -1.0
# ep 6: (match 11) game finished, reward: -1.0
# ep 6: (match 12) game finished, reward: -1.0
# ep 6: (match 13) game finished, reward: -1.0
# ep 6: (match 14) game finished, reward: -1.0
# ep 6: (match 15) game finished, reward: -1.0
# ep 6: (match 16) game finished, reward: -1.0
# ep 6: (match 17) game finished, reward: -1.0
# ep 6: (match 18) game finished, reward: -1.0
# ep 6: (match 19) game finished, reward: -1.0
# ep 6: (match 20) game finished, reward: -1.0
# ep 6: (match 21) game finished, reward: -1.0
# ep 6: (match 22) game finished, reward: -1.0
# resetting env. episode reward total was -20.0
# total matches played in this episode: 22, Note: To change episode, one player should win 21 matches.
# ep 7: (match 1) game finished, reward: 1.0
# ep 7: (match 2) game finished, reward: -1.0
# ep 7: (match 3) game finished, reward: -1.0
# ep 7: (match 4) game finished, reward: -1.0
# ep 7: (match 5) game finished, reward: -1.0
# ep 7: (match 6) game finished, reward: -1.0
# ep 7: (match 7) game finished, reward: -1.0
# ep 7: (match 8) game finished, reward: -1.0
# ep 7: (match 9) game finished, reward: -1.0
# ep 7: (match 10) game finished, reward: -1.0
# ep 7: (match 11) game finished, reward: -1.0
# ep 7: (match 12) game finished, reward: -1.0
# ep 7: (match 13) game finished, reward: -1.0
# ep 7: (match 14) game finished, reward: -1.0
# ep 7: (match 15) game finished, reward: -1.0
# ep 7: (match 16) game finished, reward: -1.0
# ep 7: (match 17) game finished, reward: -1.0
# ep 7: (match 18) game finished, reward: -1.0
# ep 7: (match 19) game finished, reward: -1.0
# ep 7: (match 20) game finished, reward: -1.0
# ep 7: (match 21) game finished, reward: -1.0
# ep 7: (match 22) game finished, reward: -1.0
# loss : 1.1563747648324352e-07
# resetting env. episode reward total was -20.0
# total matches played in this episode: 22, Note: To change episode, one player should win 21 matches.
# ep 8: (match 1) game finished, reward: -1.0
# ep 8: (match 2) game finished, reward: -1.0
# ep 8: (match 3) game finished, reward: -1.0
# ep 8: (match 4) game finished, reward: -1.0
# ep 8: (match 5) game finished, reward: -1.0
# ep 8: (match 6) game finished, reward: -1.0
# ep 8: (match 7) game finished, reward: -1.0
# ep 8: (match 8) game finished, reward: -1.0
# ep 8: (match 9) game finished, reward: -1.0
# ep 8: (match 10) game finished, reward: -1.0
# ep 8: (match 11) game finished, reward: -1.0
# ep 8: (match 12) game finished, reward: -1.0
# ep 8: (match 13) game finished, reward: -1.0
# ep 8: (match 14) game finished, reward: -1.0
# ep 8: (match 15) game finished, reward: -1.0
# ep 8: (match 16) game finished, reward: -1.0
# ep 8: (match 17) game finished, reward: -1.0
# ep 8: (match 18) game finished, reward: -1.0
# ep 8: (match 19) game finished, reward: -1.0
# ep 8: (match 20) game finished, reward: -1.0
# ep 8: (match 21) game finished, reward: -1.0
# resetting env. episode reward total was -21.0
# total matches played in this episode: 21, Note: To change episode, one player should win 21 matches.
# ep 9: (match 1) game finished, reward: -1.0
# ep 9: (match 2) game finished, reward: -1.0
# ep 9: (match 3) game finished, reward: -1.0
# ep 9: (match 4) game finished, reward: -1.0
# ep 9: (match 5) game finished, reward: -1.0
# ep 9: (match 6) game finished, reward: -1.0
# ep 9: (match 7) game finished, reward: -1.0
# ep 9: (match 8) game finished, reward: -1.0
# ep 9: (match 9) game finished, reward: -1.0
# ep 9: (match 10) game finished, reward: -1.0
# ep 9: (match 11) game finished, reward: -1.0
# ep 9: (match 12) game finished, reward: -1.0
# ep 9: (match 13) game finished, reward: 1.0
# ep 9: (match 14) game finished, reward: -1.0
# ep 9: (match 15) game finished, reward: -1.0
# ep 9: (match 16) game finished, reward: -1.0
# ep 9: (match 17) game finished, reward: -1.0
# ep 9: (match 18) game finished, reward: -1.0
# ep 9: (match 19) game finished, reward: -1.0
# ep 9: (match 20) game finished, reward: -1.0
# ep 9: (match 21) game finished, reward: 1.0
# ep 9: (match 22) game finished, reward: -1.0
# ep 9: (match 23) game finished, reward: -1.0
# loss : 5.684366755076553e-08
# resetting env. episode reward total was -19.0
# total matches played in this episode: 23, Note: To change episode, one player should win 21 matches.
# ep 10: (match 1) game finished, reward: -1.0
# ep 10: (match 2) game finished, reward: -1.0
# ep 10: (match 3) game finished, reward: -1.0
# ep 10: (match 4) game finished, reward: -1.0
# ep 10: (match 5) game finished, reward: -1.0
# ep 10: (match 6) game finished, reward: -1.0
# ep 10: (match 7) game finished, reward: -1.0
# ep 10: (match 8) game finished, reward: -1.0
# ep 10: (match 9) game finished, reward: -1.0
# ep 10: (match 10) game finished, reward: -1.0
# ep 10: (match 11) game finished, reward: -1.0
# ep 10: (match 12) game finished, reward: -1.0
# ep 10: (match 13) game finished, reward: -1.0
# ep 10: (match 14) game finished, reward: -1.0
# ep 10: (match 15) game finished, reward: -1.0
# ep 10: (match 16) game finished, reward: -1.0
# ep 10: (match 17) game finished, reward: -1.0
# ep 10: (match 18) game finished, reward: -1.0
# ep 10: (match 19) game finished, reward: -1.0
# ep 10: (match 20) game finished, reward: -1.0
# ep 10: (match 21) game finished, reward: -1.0
# resetting env. episode reward total was -21.0
# total matches played in this episode: 21, Note: To change episode, one player should win 21 matches.
# ep 11: (match 1) game finished, reward: -1.0
# ep 11: (match 2) game finished, reward: -1.0
# ep 11: (match 3) game finished, reward: -1.0
# ep 11: (match 4) game finished, reward: -1.0
# ep 11: (match 5) game finished, reward: -1.0
# ep 11: (match 6) game finished, reward: -1.0
# ep 11: (match 7) game finished, reward: -1.0
# ep 11: (match 8) game finished, reward: -1.0
# ep 11: (match 9) game finished, reward: -1.0
# ep 11: (match 10) game finished, reward: -1.0
# ep 11: (match 11) game finished, reward: -1.0
# ep 11: (match 12) game finished, reward: -1.0
# ep 11: (match 13) game finished, reward: -1.0
# ep 11: (match 14) game finished, reward: -1.0
# ep 11: (match 15) game finished, reward: -1.0
# ep 11: (match 16) game finished, reward: -1.0
# ep 11: (match 17) game finished, reward: 1.0
# ep 11: (match 18) game finished, reward: -1.0
# ep 11: (match 19) game finished, reward: -1.0
# ep 11: (match 20) game finished, reward: -1.0
# ep 11: (match 21) game finished, reward: -1.0
# ep 11: (match 22) game finished, reward: -1.0
# loss : 9.676514700629468e-09
# resetting env. episode reward total was -20.0
# total matches played in this episode: 22, Note: To change episode, one player should win 21 matches.
# ep 12: (match 1) game finished, reward: -1.0
# ep 12: (match 2) game finished, reward: -1.0
# ep 12: (match 3) game finished, reward: -1.0
# ep 12: (match 4) game finished, reward: -1.0
# ep 12: (match 5) game finished, reward: -1.0
# ep 12: (match 6) game finished, reward: -1.0
# ep 12: (match 7) game finished, reward: -1.0
# ep 12: (match 8) game finished, reward: -1.0
# ep 12: (match 9) game finished, reward: -1.0
# ep 12: (match 10) game finished, reward: -1.0
# ep 12: (match 11) game finished, reward: -1.0
# ep 12: (match 12) game finished, reward: -1.0
# ep 12: (match 13) game finished, reward: -1.0
# ep 12: (match 14) game finished, reward: -1.0
# ep 12: (match 15) game finished, reward: -1.0
# ep 12: (match 16) game finished, reward: -1.0
# ep 12: (match 17) game finished, reward: -1.0
# ep 12: (match 18) game finished, reward: -1.0
# ep 12: (match 19) game finished, reward: -1.0
# ep 12: (match 20) game finished, reward: -1.0
# ep 12: (match 21) game finished, reward: -1.0
# resetting env. episode reward total was -21.0
# total matches played in this episode: 21, Note: To change episode, one player should win 21 matches.
# ep 13: (match 1) game finished, reward: -1.0
# ep 13: (match 2) game finished, reward: -1.0
# ep 13: (match 3) game finished, reward: -1.0
# ep 13: (match 4) game finished, reward: -1.0
# ep 13: (match 5) game finished, reward: -1.0
# ep 13: (match 6) game finished, reward: -1.0
# ep 13: (match 7) game finished, reward: -1.0
# ep 13: (match 8) game finished, reward: -1.0
# ep 13: (match 9) game finished, reward: -1.0
# ep 13: (match 10) game finished, reward: -1.0
# ep 13: (match 11) game finished, reward: -1.0
# ep 13: (match 12) game finished, reward: -1.0
# ep 13: (match 13) game finished, reward: -1.0
# ep 13: (match 14) game finished, reward: -1.0
# ep 13: (match 15) game finished, reward: -1.0
# ep 13: (match 16) game finished, reward: -1.0
# ep 13: (match 17) game finished, reward: -1.0
# ep 13: (match 18) game finished, reward: -1.0
# ep 13: (match 19) game finished, reward: -1.0
# ep 13: (match 20) game finished, reward: -1.0
# ep 13: (match 21) game finished, reward: -1.0
# loss : -2.8973627053119344e-08
# resetting env. episode reward total was -21.0
# total matches played in this episode: 21, Note: To change episode, one player should win 21 matches.
# ep 14: (match 1) game finished, reward: -1.0
# ep 14: (match 2) game finished, reward: -1.0
# ep 14: (match 3) game finished, reward: -1.0
# ep 14: (match 4) game finished, reward: -1.0
# ep 14: (match 5) game finished, reward: -1.0
# ep 14: (match 6) game finished, reward: -1.0
# ep 14: (match 7) game finished, reward: -1.0
# ep 14: (match 8) game finished, reward: -1.0
# ep 14: (match 9) game finished, reward: -1.0
# ep 14: (match 10) game finished, reward: -1.0
# ep 14: (match 11) game finished, reward: 1.0
# ep 14: (match 12) game finished, reward: -1.0
# ep 14: (match 13) game finished, reward: -1.0
# ep 14: (match 14) game finished, reward: -1.0
# ep 14: (match 15) game finished, reward: -1.0
# ep 14: (match 16) game finished, reward: -1.0
# ep 14: (match 17) game finished, reward: -1.0
# ep 14: (match 18) game finished, reward: -1.0
# ep 14: (match 19) game finished, reward: -1.0
# ep 14: (match 20) game finished, reward: -1.0
# ep 14: (match 21) game finished, reward: -1.0
# ep 14: (match 22) game finished, reward: -1.0
# resetting env. episode reward total was -20.0
# total matches played in this episode: 22, Note: To change episode, one player should win 21 matches.
# ep 15: (match 1) game finished, reward: -1.0
# ep 15: (match 2) game finished, reward: -1.0
# ep 15: (match 3) game finished, reward: -1.0
# ep 15: (match 4) game finished, reward: -1.0
# ep 15: (match 5) game finished, reward: -1.0
# ep 15: (match 6) game finished, reward: -1.0
# ep 15: (match 7) game finished, reward: -1.0
# ep 15: (match 8) game finished, reward: -1.0
# ep 15: (match 9) game finished, reward: -1.0
# ep 15: (match 10) game finished, reward: -1.0
# ep 15: (match 11) game finished, reward: -1.0
# ep 15: (match 12) game finished, reward: -1.0
# ep 15: (match 13) game finished, reward: -1.0
# ep 15: (match 14) game finished, reward: -1.0
# ep 15: (match 15) game finished, reward: -1.0
# ep 15: (match 16) game finished, reward: -1.0
# ep 15: (match 17) game finished, reward: -1.0
# ep 15: (match 18) game finished, reward: -1.0
# ep 15: (match 19) game finished, reward: -1.0
# ep 15: (match 20) game finished, reward: -1.0
# ep 15: (match 21) game finished, reward: -1.0
# loss : -3.5369790651884614e-08
# resetting env. episode reward total was -21.0
# total matches played in this episode: 21, Note: To change episode, one player should win 21 matches.
# ep 16: (match 1) game finished, reward: -1.0
# ep 16: (match 2) game finished, reward: -1.0
# ep 16: (match 3) game finished, reward: -1.0
# ep 16: (match 4) game finished, reward: -1.0
# ep 16: (match 5) game finished, reward: -1.0
# ep 16: (match 6) game finished, reward: -1.0
# ep 16: (match 7) game finished, reward: -1.0
# ep 16: (match 8) game finished, reward: -1.0
# ep 16: (match 9) game finished, reward: -1.0
# ep 16: (match 10) game finished, reward: -1.0
# ep 16: (match 11) game finished, reward: -1.0
# ep 16: (match 12) game finished, reward: -1.0
# ep 16: (match 13) game finished, reward: -1.0
# ep 16: (match 14) game finished, reward: -1.0
# ep 16: (match 15) game finished, reward: -1.0
# ep 16: (match 16) game finished, reward: -1.0
# ep 16: (match 17) game finished, reward: -1.0
# ep 16: (match 18) game finished, reward: -1.0
# ep 16: (match 19) game finished, reward: -1.0
# ep 16: (match 20) game finished, reward: -1.0
# ep 16: (match 21) game finished, reward: -1.0
# resetting env. episode reward total was -21.0
# total matches played in this episode: 21, Note: To change episode, one player should win 21 matches.
# ep 17: (match 1) game finished, reward: -1.0
# ep 17: (match 2) game finished, reward: -1.0
# ep 17: (match 3) game finished, reward: -1.0
# ep 17: (match 4) game finished, reward: -1.0
# ep 17: (match 5) game finished, reward: -1.0
# ep 17: (match 6) game finished, reward: -1.0
# ep 17: (match 7) game finished, reward: -1.0
# ep 17: (match 8) game finished, reward: -1.0
# ep 17: (match 9) game finished, reward: -1.0
# ep 17: (match 10) game finished, reward: -1.0
# ep 17: (match 11) game finished, reward: -1.0
# ep 17: (match 12) game finished, reward: -1.0
# ep 17: (match 13) game finished, reward: -1.0
# ep 17: (match 14) game finished, reward: -1.0
# ep 17: (match 15) game finished, reward: -1.0
# ep 17: (match 16) game finished, reward: -1.0
# ep 17: (match 17) game finished, reward: -1.0
# ep 17: (match 18) game finished, reward: -1.0
# ep 17: (match 19) game finished, reward: -1.0
# ep 17: (match 20) game finished, reward: -1.0
# ep 17: (match 21) game finished, reward: -1.0
# loss : -1.2754902911638055e-07
# resetting env. episode reward total was -21.0
# total matches played in this episode: 21, Note: To change episode, one player should win 21 matches.
# ep 18: (match 1) game finished, reward: -1.0
# ep 18: (match 2) game finished, reward: -1.0
# ep 18: (match 3) game finished, reward: -1.0
# ep 18: (match 4) game finished, reward: -1.0
# ep 18: (match 5) game finished, reward: -1.0
# ep 18: (match 6) game finished, reward: -1.0
# ep 18: (match 7) game finished, reward: -1.0
# ep 18: (match 8) game finished, reward: -1.0
# ep 18: (match 9) game finished, reward: 1.0
# ep 18: (match 10) game finished, reward: -1.0
# ep 18: (match 11) game finished, reward: -1.0
# ep 18: (match 12) game finished, reward: -1.0
# ep 18: (match 13) game finished, reward: -1.0
# ep 18: (match 14) game finished, reward: 1.0
# ep 18: (match 15) game finished, reward: -1.0
# ep 18: (match 16) game finished, reward: -1.0
# ep 18: (match 17) game finished, reward: -1.0
# ep 18: (match 18) game finished, reward: -1.0
# ep 18: (match 19) game finished, reward: -1.0
# ep 18: (match 20) game finished, reward: -1.0
# ep 18: (match 21) game finished, reward: -1.0
# ep 18: (match 22) game finished, reward: -1.0
# ep 18: (match 23) game finished, reward: -1.0
# resetting env. episode reward total was -19.0
# total matches played in this episode: 23, Note: To change episode, one player should win 21 matches.
# ep 19: (match 1) game finished, reward: -1.0
# ep 19: (match 2) game finished, reward: -1.0
# ep 19: (match 3) game finished, reward: -1.0
# ep 19: (match 4) game finished, reward: -1.0
# ep 19: (match 5) game finished, reward: -1.0
# ep 19: (match 6) game finished, reward: -1.0
# ep 19: (match 7) game finished, reward: -1.0
# ep 19: (match 8) game finished, reward: -1.0
# ep 19: (match 9) game finished, reward: -1.0
# ep 19: (match 10) game finished, reward: -1.0
# ep 19: (match 11) game finished, reward: -1.0
# ep 19: (match 12) game finished, reward: -1.0
# ep 19: (match 13) game finished, reward: -1.0
# ep 19: (match 14) game finished, reward: -1.0
# ep 19: (match 15) game finished, reward: -1.0
# ep 19: (match 16) game finished, reward: -1.0
# ep 19: (match 17) game finished, reward: -1.0
# ep 19: (match 18) game finished, reward: -1.0
# ep 19: (match 19) game finished, reward: -1.0
# ep 19: (match 20) game finished, reward: -1.0
# ep 19: (match 21) game finished, reward: -1.0
# loss : -7.816417735284631e-08
# resetting env. episode reward total was -21.0
# total matches played in this episode: 21, Note: To change episode, one player should win 21 matches.
# ep 20: (match 1) game finished, reward: -1.0
# ep 20: (match 2) game finished, reward: -1.0
# ep 20: (match 3) game finished, reward: -1.0
# ep 20: (match 4) game finished, reward: -1.0
# ep 20: (match 5) game finished, reward: -1.0
# ep 20: (match 6) game finished, reward: -1.0
# ep 20: (match 7) game finished, reward: -1.0
# ep 20: (match 8) game finished, reward: -1.0
# ep 20: (match 9) game finished, reward: -1.0
# ep 20: (match 10) game finished, reward: -1.0
# ep 20: (match 11) game finished, reward: -1.0
# ep 20: (match 12) game finished, reward: -1.0
# ep 20: (match 13) game finished, reward: 1.0
# ep 20: (match 14) game finished, reward: -1.0
# ep 20: (match 15) game finished, reward: -1.0
# ep 20: (match 16) game finished, reward: -1.0
# ep 20: (match 17) game finished, reward: -1.0
# ep 20: (match 18) game finished, reward: -1.0
# ep 20: (match 19) game finished, reward: -1.0
# ep 20: (match 20) game finished, reward: -1.0
# ep 20: (match 21) game finished, reward: -1.0
# ep 20: (match 22) game finished, reward: -1.0
# resetting env. episode reward total was -20.0
# total matches played in this episode: 22, Note: To change episode, one player should win 21 matches.
# ep 21: (match 1) game finished, reward: -1.0
# ep 21: (match 2) game finished, reward: -1.0
# ep 21: (match 3) game finished, reward: -1.0
# ep 21: (match 4) game finished, reward: -1.0
# ep 21: (match 5) game finished, reward: -1.0
# ep 21: (match 6) game finished, reward: -1.0
# ep 21: (match 7) game finished, reward: -1.0
# ep 21: (match 8) game finished, reward: -1.0
# ep 21: (match 9) game finished, reward: -1.0
# ep 21: (match 10) game finished, reward: -1.0
# ep 21: (match 11) game finished, reward: -1.0
# ep 21: (match 12) game finished, reward: -1.0
# ep 21: (match 13) game finished, reward: -1.0
# ep 21: (match 14) game finished, reward: 1.0
# ep 21: (match 15) game finished, reward: -1.0
# ep 21: (match 16) game finished, reward: -1.0
# ep 21: (match 17) game finished, reward: -1.0
# ep 21: (match 18) game finished, reward: -1.0
# ep 21: (match 19) game finished, reward: -1.0
# ep 21: (match 20) game finished, reward: -1.0
# ep 21: (match 21) game finished, reward: -1.0
# ep 21: (match 22) game finished, reward: -1.0
# loss : 5.605588881962831e-08
# resetting env. episode reward total was -20.0
# total matches played in this episode: 22, Note: To change episode, one player should win 21 matches.
# ep 22: (match 1) game finished, reward: -1.0
# ep 22: (match 2) game finished, reward: -1.0
# ep 22: (match 3) game finished, reward: -1.0
# ep 22: (match 4) game finished, reward: -1.0
# ep 22: (match 5) game finished, reward: -1.0
# ep 22: (match 6) game finished, reward: -1.0
# ep 22: (match 7) game finished, reward: -1.0
# ep 22: (match 8) game finished, reward: -1.0
# ep 22: (match 9) game finished, reward: -1.0
# ep 22: (match 10) game finished, reward: -1.0
# ep 22: (match 11) game finished, reward: -1.0
# ep 22: (match 12) game finished, reward: -1.0
# ep 22: (match 13) game finished, reward: -1.0
# ep 22: (match 14) game finished, reward: -1.0
# ep 22: (match 15) game finished, reward: 1.0
# ep 22: (match 16) game finished, reward: -1.0
# ep 22: (match 17) game finished, reward: -1.0
# ep 22: (match 18) game finished, reward: -1.0
# ep 22: (match 19) game finished, reward: -1.0
# ep 22: (match 20) game finished, reward: -1.0
# ep 22: (match 21) game finished, reward: -1.0
# ep 22: (match 22) game finished, reward: -1.0
# resetting env. episode reward total was -20.0
# total matches played in this episode: 22, Note: To change episode, one player should win 21 matches.
# ep 23: (match 1) game finished, reward: -1.0
# ep 23: (match 2) game finished, reward: -1.0
# ep 23: (match 3) game finished, reward: -1.0
# ep 23: (match 4) game finished, reward: -1.0
# ep 23: (match 5) game finished, reward: -1.0
# ep 23: (match 6) game finished, reward: -1.0
# ep 23: (match 7) game finished, reward: -1.0
# ep 23: (match 8) game finished, reward: -1.0
# ep 23: (match 9) game finished, reward: -1.0
# ep 23: (match 10) game finished, reward: -1.0
# ep 23: (match 11) game finished, reward: -1.0
# ep 23: (match 12) game finished, reward: -1.0
# ep 23: (match 13) game finished, reward: -1.0
# ep 23: (match 14) game finished, reward: -1.0
# ep 23: (match 15) game finished, reward: -1.0
# ep 23: (match 16) game finished, reward: -1.0
# ep 23: (match 17) game finished, reward: -1.0
# ep 23: (match 18) game finished, reward: -1.0
# ep 23: (match 19) game finished, reward: -1.0
# ep 23: (match 20) game finished, reward: -1.0
# ep 23: (match 21) game finished, reward: -1.0
# loss : -3.0784818250140233e-08
# resetting env. episode reward total was -21.0
# total matches played in this episode: 21, Note: To change episode, one player should win 21 matches.
# ep 24: (match 1) game finished, reward: -1.0
# ep 24: (match 2) game finished, reward: -1.0
# ep 24: (match 3) game finished, reward: -1.0
# ep 24: (match 4) game finished, reward: -1.0
# ep 24: (match 5) game finished, reward: -1.0
# ep 24: (match 6) game finished, reward: -1.0
# ep 24: (match 7) game finished, reward: -1.0
# ep 24: (match 8) game finished, reward: -1.0
# ep 24: (match 9) game finished, reward: -1.0
# ep 24: (match 10) game finished, reward: -1.0
# ep 24: (match 11) game finished, reward: -1.0
# ep 24: (match 12) game finished, reward: -1.0
# ep 24: (match 13) game finished, reward: -1.0
# ep 24: (match 14) game finished, reward: -1.0
# ep 24: (match 15) game finished, reward: -1.0
# ep 24: (match 16) game finished, reward: -1.0
# ep 24: (match 17) game finished, reward: -1.0
# ep 24: (match 18) game finished, reward: -1.0
# ep 24: (match 19) game finished, reward: -1.0
# ep 24: (match 20) game finished, reward: -1.0
# ep 24: (match 21) game finished, reward: -1.0
# resetting env. episode reward total was -21.0
# total matches played in this episode: 21, Note: To change episode, one player should win 21 matches.
# ep 25: (match 1) game finished, reward: -1.0
# ep 25: (match 2) game finished, reward: -1.0
# ep 25: (match 3) game finished, reward: -1.0
# ep 25: (match 4) game finished, reward: -1.0
# ep 25: (match 5) game finished, reward: -1.0
# ep 25: (match 6) game finished, reward: -1.0
# ep 25: (match 7) game finished, reward: -1.0
# ep 25: (match 8) game finished, reward: -1.0
# ep 25: (match 9) game finished, reward: -1.0
# ep 25: (match 10) game finished, reward: -1.0
# ep 25: (match 11) game finished, reward: -1.0
# ep 25: (match 12) game finished, reward: -1.0
# ep 25: (match 13) game finished, reward: -1.0
# ep 25: (match 14) game finished, reward: -1.0
# ep 25: (match 15) game finished, reward: -1.0
# ep 25: (match 16) game finished, reward: -1.0
# ep 25: (match 17) game finished, reward: -1.0
# ep 25: (match 18) game finished, reward: -1.0
# ep 25: (match 19) game finished, reward: -1.0
# ep 25: (match 20) game finished, reward: -1.0
# ep 25: (match 21) game finished, reward: -1.0
# loss : 3.0806620543444296e-07
# resetting env. episode reward total was -21.0
# total matches played in this episode: 21, Note: To change episode, one player should win 21 matches.
# ep 26: (match 1) game finished, reward: -1.0
# ep 26: (match 2) game finished, reward: -1.0
# ep 26: (match 3) game finished, reward: -1.0
# ep 26: (match 4) game finished, reward: -1.0
# ep 26: (match 5) game finished, reward: -1.0
# ep 26: (match 6) game finished, reward: -1.0
# ep 26: (match 7) game finished, reward: -1.0
# ep 26: (match 8) game finished, reward: -1.0
# ep 26: (match 9) game finished, reward: -1.0
# ep 26: (match 10) game finished, reward: -1.0
# ep 26: (match 11) game finished, reward: -1.0
# ep 26: (match 12) game finished, reward: -1.0
# ep 26: (match 13) game finished, reward: -1.0
# ep 26: (match 14) game finished, reward: -1.0
# ep 26: (match 15) game finished, reward: -1.0
# ep 26: (match 16) game finished, reward: -1.0
# ep 26: (match 17) game finished, reward: -1.0
# ep 26: (match 18) game finished, reward: -1.0
# ep 26: (match 19) game finished, reward: -1.0
# ep 26: (match 20) game finished, reward: -1.0
# ep 26: (match 21) game finished, reward: -1.0
# resetting env. episode reward total was -21.0
# total matches played in this episode: 21, Note: To change episode, one player should win 21 matches.
# ep 27: (match 1) game finished, reward: -1.0
# ep 27: (match 2) game finished, reward: -1.0
# ep 27: (match 3) game finished, reward: -1.0
# ep 27: (match 4) game finished, reward: -1.0
# ep 27: (match 5) game finished, reward: -1.0
# ep 27: (match 6) game finished, reward: -1.0
# ep 27: (match 7) game finished, reward: -1.0
# ep 27: (match 8) game finished, reward: -1.0
# ep 27: (match 9) game finished, reward: -1.0
# ep 27: (match 10) game finished, reward: -1.0
# ep 27: (match 11) game finished, reward: -1.0
# ep 27: (match 12) game finished, reward: -1.0
# ep 27: (match 13) game finished, reward: -1.0
# ep 27: (match 14) game finished, reward: -1.0
# ep 27: (match 15) game finished, reward: -1.0
# ep 27: (match 16) game finished, reward: -1.0
# ep 27: (match 17) game finished, reward: -1.0
# ep 27: (match 18) game finished, reward: -1.0
# ep 27: (match 19) game finished, reward: -1.0
# ep 27: (match 20) game finished, reward: -1.0
# ep 27: (match 21) game finished, reward: -1.0
# loss : -4.1208149781368775e-08
# resetting env. episode reward total was -21.0
# total matches played in this episode: 21, Note: To change episode, one player should win 21 matches.
# ep 28: (match 1) game finished, reward: -1.0
# ep 28: (match 2) game finished, reward: -1.0
# ep 28: (match 3) game finished, reward: -1.0
# ep 28: (match 4) game finished, reward: -1.0
# ep 28: (match 5) game finished, reward: -1.0
# ep 28: (match 6) game finished, reward: -1.0
# ep 28: (match 7) game finished, reward: -1.0
# ep 28: (match 8) game finished, reward: -1.0
# ep 28: (match 9) game finished, reward: -1.0
# ep 28: (match 10) game finished, reward: -1.0
# ep 28: (match 11) game finished, reward: -1.0
# ep 28: (match 12) game finished, reward: -1.0
# ep 28: (match 13) game finished, reward: -1.0
# ep 28: (match 14) game finished, reward: -1.0
# ep 28: (match 15) game finished, reward: -1.0
# ep 28: (match 16) game finished, reward: -1.0
# ep 28: (match 17) game finished, reward: -1.0
# ep 28: (match 18) game finished, reward: 1.0
# ep 28: (match 19) game finished, reward: -1.0
# ep 28: (match 20) game finished, reward: -1.0
# ep 28: (match 21) game finished, reward: -1.0
# ep 28: (match 22) game finished, reward: -1.0
# resetting env. episode reward total was -20.0
# total matches played in this episode: 22, Note: To change episode, one player should win 21 matches.
# ep 29: (match 1) game finished, reward: -1.0
# ep 29: (match 2) game finished, reward: -1.0
# ep 29: (match 3) game finished, reward: -1.0
# ep 29: (match 4) game finished, reward: -1.0
# ep 29: (match 5) game finished, reward: -1.0
# ep 29: (match 6) game finished, reward: -1.0
# ep 29: (match 7) game finished, reward: -1.0
# ep 29: (match 8) game finished, reward: -1.0
# ep 29: (match 9) game finished, reward: -1.0
# ep 29: (match 10) game finished, reward: -1.0
# ep 29: (match 11) game finished, reward: -1.0
# ep 29: (match 12) game finished, reward: -1.0
# ep 29: (match 13) game finished, reward: -1.0
# ep 29: (match 14) game finished, reward: -1.0
# ep 29: (match 15) game finished, reward: -1.0
# ep 29: (match 16) game finished, reward: -1.0
# ep 29: (match 17) game finished, reward: -1.0
# ep 29: (match 18) game finished, reward: -1.0
# ep 29: (match 19) game finished, reward: -1.0
# ep 29: (match 20) game finished, reward: -1.0
# ep 29: (match 21) game finished, reward: -1.0
# loss : -1.225138532845449e-07
# resetting env. episode reward total was -21.0
# total matches played in this episode: 21, Note: To change episode, one player should win 21 matches.
